# %% [markdown]
# ---
#
# Running pRF and vwfa localizer
#
# ---

# %%
# autoload
# %load_ext autoreload
# %autoreload 2

# Load PGL libraries
from pgl import pgl, pglExperiment, pglFixationTaskLeftRight, pglVWFATask, pglBarTask
pgl = pgl()

# close any existing windows
pgl.cleanUp()
# Out:
# (pgl) Warning: pylink not found, pglEyelink class will not be available. Download with: pip install sr-research-pylink
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.13 | packaged by conda-forge | (main, Mar  5 2026, 17:06:14) [Clang 19.1.7 ]
# (pgl:checkOS) Running on Mac mini (Macmini9,1) with macOS version: 26.4
# (pgl:checkOS) Apple M1 Cores: 8 (4 Performance and 4 Efficiency) Memory: 8 GB
# (pgl:checkOS) GPU: Apple M1 (Built-In) 8 cores, Metal 4 support
# (pgl:checkOS)   Acer K272HUL [Main Display]: 2560 x 1440 (QHD/WQHD - Wide Quad High Definition) (Unknown type) GammaTable size: 1024
# (pgl:checkOS)   KEY DIGITAL14: 1920 x 1080 (1080p FHD - Full High Definition) (Unknown type) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglBase:shutdownAll) Shutting down mglMetal process: 57063
# (pglBase:removeOrphanedSockets) Removing orphaned socket: /Users/gru/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260806_213543.ecWvhmrJon
# (pglBase:removeOrphanedSockets) Removed 1 orphaned sockets

# %% [markdown]
# ---
#
# Test display settings
#
#   * Run this to set the monitor settings (distance, size, calibration settings etc).
#   * Find the display that you will be using, and click on Test to make sure it works
#   * Hit ESC to end test
#
# ---

# %%
pgl.displaySettings()

# %% [markdown]
# ---
#
# Test settings:
#
#   * Run this to set general experiment settings (which display, gamma setting, response keys, etc)
#   * Also run Test here to make sure your settings work as expected
#   * Hit ESC to end test
#
# ---

# %%
pgl.settings()

# %% [markdown]
# <div style="background-color:#e6f4ea; padding:15px; border-left:6px solid #2e7d32; color:#1b4332; font-size:18px;">
# <b>Set subjectID</b>
# </div>

# %%
subjectID="s0006"

# %% [markdown]
# <div style="background-color:#e6f4ea; padding:15px; border-left:6px solid #2e7d32; color:#1b4332; font-size:18px;">
# <b>Set settings name: Name of settings from above that will be used to run the experiment (Set to None to use default)
# </div>

# %%
settingsName = None

# %% [markdown]
# ---
#
# pRF Experiment
#
# ---

# %%
# Set up experiment
e = pglExperiment(pgl, settingsName=settingsName, experimentName="pglBarTask", subjectID=subjectID)

# initialize tasks
fixationTask = pglFixationTaskLeftRight(pgl)
barTask = pglBarTask(pgl, randomSeed=42)

# add the tasks to the experiment
e.addTask(barTask)
e.addTask(fixationTask)

# init screen
e.initScreen()

# run experiment
e.run()

# display results
e.display()

# %% [markdown]
# ---
#
# vwfa experiment
#
# ---

# %% [markdown]
# <div style="background-color:#e6f4ea; padding:15px; border-left:6px solid #2e7d32; color:#1b4332; font-size:18px;">
# <b>Make sure to set the runNum that you want for each run</b><br>
# Make sure stimulus folder points to the correct folder
# </div>

# %%
# initialize experiment
e = pglExperiment(pgl, settingsName=settingsName, experimentName='VWFA', subjectID=subjectID)

# Path to folder containing stimulus .mat files
stimulusFolder = "/Users/gru/proj/2026_C-Sharp_VWFA"

# initialize VWFA task
# run 1 → 1-12, run 2 → 13-24, run 3 → 25-36
vwfaTask = pglVWFATask(pgl, stimulusFolder=stimulusFolder, runNum=3, repeatForever=False)

# add the tasks to the experiment
e.addTask(vwfaTask)

# init screen
e.initScreen()

# run experiment
e.run()

# display results
e.display()
# Out:
# pglSettings:
# ----------------------------------------
# name                           windowed
# uuid                           084589ef-ec13-4776-9121-e31eb25184d4
# isDefault                      True
# pglVersion                     unknown
# github                         35aadb6b35f714407fad60f2e3ef404febc6d6ee
# version                        1.0
# choose display                 [<pgl.pglSettings.pglDisplaySettingsWindowed object at 0x1688d4530>, <pgl.pglSettings.pglDisplaySettings object at 0x1688d56a0>, <pgl.pglSettings.pglDisplaySettings object at 0x1688d4110>]
# calibrateForGamma              [0.0, 1.0, 2.2]
# dataPath                       ~/data
# startKey                       space
# endKey                         escape
# volumeTriggerKey               5
# responseKeys                   12346789
# ignoreInitialVolumes           4
# eatKeys                        True
# startOnVolumeTrigger           False
# manualPreStart                 False
# closeScreenOnEnd               True
# backgroundColor                [0.5, 0.5, 0.5]
# eyetracker                     ['None', 'Eyelink']
# (pglBase:removeOrphanedSockets) No orphaned sockets found in /Users/gru/Library/Containers/gru.mglMetal/Data
# ================================= pglBase:open =================================
# (pgl:_resolution:getResolution) Display 0/2: 2560x1440 60Hz 32bits
# (pgl->pglBase:open) Starting mglMetal application: /Users/gru/proj/pgl/metal/mglMetal.app
# (pgl->pglBase:open) Using socket with address: /Users/gru/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260806_213850.S7KSJu0uIu
# (pgl:_pglComm) .Connected to: /Users/gru/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260806_213850.S7KSJu0uIu
# (pgl:_resolution:getResolution) Display 0/2: 2560x1440 60Hz 32bits
# (pgl:pglTransform:pix2deg) xPix2Deg and yPix2Deg must be set before calling this function.
# (pgl->pglMessages:oneTimeWarning) ⚠️ Need to fix clearScreen which is not functioning properly, drawing a full screen quad instead. ⚠️
# ================================================================================
# (pglKeyboardMouse:start) Starting keyboard and mouse event listener.
# (pglDevices) Added device: pglKeyboard
# (pglEventListener) Eating 11 keys: ['1', '2', '3', '4', '5', '6', '7', '8', '9', 'escape', 'space']
# Block 1: 108 trials randomized over: ['condition', 'instance']
# (VWFA Task) Trial 1: condition=4 instance=27
# (pglVWFATask)   names=['pseudowordsCourier_49.mat', 'pseudowordsCourier_5.mat', 'pseudowordsCourier_50.mat', 'pseudowordsCourier_51.mat'] | isRepeat=False
# (pglExperiment:startPhase) Starting phase: 0/1
# (pglExperiment:run) Experiment started.
# (VWFA Task) Trial 2: condition=5 instance=34
# (pglVWFATask)   names=['consonantsSloan_74.mat', 'consonantsSloan_75.mat', 'consonantsSloan_76.mat', 'consonantsSloan_77.mat'] | isRepeat=False
# (VWFA Task) Trial 3: condition=7 instance=35
# (pglVWFATask)   names=['PseudoSloan_highFreqWords_78 8.22.15\u202fPM.mat', 'PseudoSloan_highFreqWords_79 8.22.15\u202fPM.mat', 'PseudoSloan_highFreqWords_79 8.22.15\u202fPM.mat', 'PseudoSloan_highFreqWords_80 8.22.15\u202fPM.mat'] | isRepeat=True
# (VWFA Task) Trial 4: condition=6 instance=31
# (pglVWFATask)   names=['consonantsCourier_63.mat', 'consonantsCourier_64.mat', 'consonantsCourier_65.mat', 'consonantsCourier_66.mat'] | isRepeat=False
# Ending task VWFA Task
# (pglExperiment:run) Experiment done.
# (pglExperiment:save) Saving experiment data to: /Users/gru/data/vwfa/s0006/session_2026-08-06/run_21-38-50
# (pglSettings:save) Saved display settings to /Users/gru/data/vwfa/s0006/session_2026-08-06/run_21-38-50/settings.json
# (pglParameter:save) Saving parameter condition_instance to: /Users/gru/data/vwfa/s0006/session_2026-08-06/run_21-38-50/vWFATask/parameters/condition_instance
# (pglExperiment:endScreen) Stopping keyboard/mouse device.
# <pglDevice type=pglKeyboard>
# (pglKeyboardMouse:stop) Stopping keyboard listener.
# (pglExperiment:endScreen) Restoring gamma table
# (pglExperiment:endScreen) Restoring original gamma table
# ================================ pglBase:close =================================
# (pglBase:close) Closing connection to mglMetal application
# (pgl->pglBase:close) Closing mglMetal application with PID 57146
# (pgl->pglBase:close) mglMetal application with PID: 57146 was killed successfully.
# (pgl:_pglComm) Closed socket: /Users/gru/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260806_213850.S7KSJu0uIu
# ================================================================================
