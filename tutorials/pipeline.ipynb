# %% [markdown]
# ---
#
# Pipelines
#
# ---

# %%
# autoload
# %load_ext autoreload
# %autoreload 2

# Load PGL libraries and start a PGL window
from pgl import pgl, pglChoose
from pgl.pglPipeline import pglChooseExperiment
pgl = pgl()

# close any existing windows
pgl.cleanUp()

# %% [markdown]
# ---
#
# Basic action which loads an experiment
#
# ---

# %%
s = pglChoose(dataPath="/Users/justin/data")
pgl.traitsDialog(s)

# %%
s = pglChooseExperiment(dataPath="/Users/justin/data/randomdots")
pgl.traitsDialog(s)

# %%
from pgl.pglPipeline import pglActionLoadSession

a = pglActionLoadSession()
a.configure(dataPath='ssh://gru@cointreau/Users/gru/data/vwfa')
output = a.run()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/sshfs/utils.py:27, in wrap_exceptions.<locals>.wrapper(*args, **kwargs)
#      26 try:
# ---> 27     return await func(*args, **kwargs)
#      28 except PermissionDenied as exc:
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/sshfs/spec.py:270, in SSHFileSystem._ls(self, path, detail, **kwargs)
#     269 async with self._pool.get() as channel:
# --> 270     file_attrs = await channel.readdir(path)
#     272 infos = []
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/asyncssh/sftp.py:5593, in SFTPClient.readdir(self, path)
#    5575 """Read the contents of a remote directory
#    5576
#    5577    This method reads the contents of a directory, returning
#    (...)   5590
#    5591 """
# -> 5593 return [entry async for entry in self.scandir(path)]
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/asyncssh/sftp.py:5552, in SFTPClient.scandir(self, path)
#    5551 dirpath = self.compose_path(path)
# -> 5552 handle = await self._handler.opendir(dirpath)
#    5553 at_end = False
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/asyncssh/sftp.py:3118, in SFTPClientHandler.opendir(self, path)
#    3116 self.logger.debug1('Sending opendir for %s', path)
# -> 3118 return cast(bytes, await self._make_request(
#    3119     FXP_OPENDIR, String(path)))
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/asyncssh/sftp.py:2684, in SFTPClientHandler._make_request(self, pkttype, *args)
#    2683 self._send_request(pkttype, args, waiter)
# -> 2684 resptype, resp = await waiter
#    2686 return_type = self._return_types.get(pkttype)
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/asyncssh/sftp.py:2582, in SFTPHandler.recv_packets(self)
#    2581 while self._reader: # pragma: no branch
# -> 2582     packet = await self.recv_packet()
#    2584     pkttype = packet.get_byte()
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/asyncssh/sftp.py:2571, in SFTPHandler.recv_packet(self)
#    2569 assert self._reader is not None
# -> 2571 pktlen = await self._reader.readexactly(4)
#    2572 pktlen = int.from_bytes(pktlen, 'big')
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/asyncssh/stream.py:239, in SSHReader.readexactly(self, n)
#     224 """Read an exact amount of data from the stream
#     225
#     226    This method is a coroutine which reads exactly n bytes or
#    (...)    236
#     237 """
# --> 239 return await self._session.read(self._datatype, n, exact=True)
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/asyncssh/stream.py:550, in SSHStreamSession.read(self, datatype, n, exact)
#     549         else:
# --> 550             raise exc
#     552 l = len(recv_buf[0])
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/asyncio/selector_events.py:1013, in _SelectorSocketTransport._read_ready__data_received(self)
#    1012 try:
# -> 1013     data = self._sock.recv(self.max_size)
#    1014 except (BlockingIOError, InterruptedError):
#
# TimeoutError: [Errno 60] Operation timed out
#
# The above exception was the direct cause of the following exception:
#
# FSTimeoutError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 from pgl.pglPipeline import pglActionLoadSession
#       3 a = pglActionLoadSession()
# ----> 4 a.configure(dataPath='ssh://gru@cointreau/Users/gru/data/vwfa')
#       5 output = s.run()
#
# File ~/proj/pgl/pgl/pglPipeline.py:460, in configure(self, dataPath)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/proj/pgl/pgl/pglPipeline.py:217, in pglRun.__init__(self, name, dataPath, filesystem, filesystemPrefix, entries)
#     212 def __init__(self, fullDataPath, filesystem, filesystemPrefix):
#     213     '''
#     214     Initialize the pglRun class
#     215
#     216     Args:
# --> 217         dataPath: The directory where the run is saved
#     218     '''
#     219     # init super
#     220     super().__init__()
#
# File ~/proj/pgl/pgl/pglPipeline.py:273, in _getChildren(self, entries)
#     270 self.filesystemPrefix = filesystemPrefix
#     272 for runPath in runList:
# --> 273     self.runs.append(pglRun(fullDataPath=runPath, filesystem=filesystem, filesystemPrefix=filesystemPrefix))
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File ~/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/fsspec/asyn.py:101, in sync(loop, func, timeout, *args, **kwargs)
#      98 return_result = result[0]
#      99 if isinstance(return_result, asyncio.TimeoutError):
#     100     # suppress asyncio.TimeoutError, raise FSTimeoutError
# --> 101     raise FSTimeoutError from return_result
#     102 elif isinstance(return_result, BaseException):
#     103     raise return_result
#
# FSTimeoutError:

# %%
from pgl.pglBase import pglBase
print(pglBase.validateFilesystem(None,'ssh://gru@cointreau/Users/gru/data/vwfa',"ssh://gru@cointreau:"))

# %%
#s.print
cointreau.storage_options

# %%
dataDir="/Users/justin/data/randomdots/s0000/20260805/run_235109"
#dataDir="/Users/justin/data/randomdots/s0000/session_2026-08-07/run_21-03-20"
from pgl.pglPipeline import pglRun
run = pglRun(dataDir)

# %%
run.print()
run.display()
