# %% [markdown]
# ---
#
# Pipelines
#
# ---

# %%
# autoload
# %load_ext autoreload
# %autoreload 2

# Load PGL libraries and start a PGL window
from pgl import pgl, pglChoose
from pgl.pglPipeline import pglActionLoadSession

pgl = pgl()

# close any existing windows
pgl.cleanUp()
# Out:
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:35:20) [Clang 16.0.6 ]
# (pgl:checkOS) Running on MacBook Pro (MacBookPro18,3) with macOS version: 26.5.1
# (pgl:checkOS) Apple M1 Pro Cores: 8 (6 Performance and 2 Efficiency) Memory: 32 GB
# (pgl:checkOS) GPU: Apple M1 Pro (Built-In) 14 cores, Metal 4 support
# (pgl:checkOS)   Color LCD [Main Display]: 3024 x 1964 Retina (Built-in Liquid Retina XDR Display) GammaTable size: 1024
# (pgl:checkOS)   LED Cinema Display: 1600 x 1000 (Unknown type) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglBase:removeOrphanedSockets) No orphaned sockets found in /Users/justin/Library/Containers/gru.mglMetal/Data

# %% [markdown]
# ---
#
# Basic action which loads an experiment
#
# ---
# Use pglActionLoadSession to load a session

# %%
# choose session to import from cointreau
a = pglActionLoadSession()
a.configure(dataPath='ssh://gru@cointreau/Users/gru/data/vwfa')
session = a.run()

# %% [markdown]
# Fix for missing volume information

# %%
# import action from pipeline
from pgl.pglPipeline import pglActionRecreateExperimentDataFromTasks

# configure action
a = pglActionRecreateExperimentDataFromTasks()
a.configure(session=session)
# Out:
# (pglRun:experimentSettings) Loading experiment settings for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-25-31
# (pglRun:experimentSettings) Loading experiment settings for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-17-29
# (pglRun:experimentSettings) Loading experiment settings for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-33-21
# (pglRun:experimentSettings) Loading experiment settings for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-41-12

# %%
fixedSession = a.run()
# Out:
# (pglRun:tasks) Loading tasks for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-25-31
# taskName: vWFATask
# (pglTask:load) Loading task data from: /Users/gru/data/vwfa/s012/session_2026-08-07/run_20-25-31/vWFATask
# (pglParameter:load) Loaded parameter condition_instance from: /Users/gru/data/vwfa/s012/session_2026-08-07/run_20-25-31/vWFATask/parameters/condition_instance
# (pglRun:settings) Loading settings for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-25-31
# (pglRun:data) Loading data for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-25-31
# (pglMessages:warning) ❌ Warning for 2 volumes beginning at 434: spacing requires -0.163s of slop (16.3% of TR) ❌
# (pglActionRecreateExperimentDataFromTasks:run) nTriggers: 436 Mean: 0.999, SD: 0.018
# (pglRun:tasks) Loading tasks for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-17-29
# taskName: vWFATask
# (pglTask:load) Loading task data from: /Users/gru/data/vwfa/s012/session_2026-08-07/run_20-17-29/vWFATask
# (pglParameter:load) Loaded parameter condition_instance from: /Users/gru/data/vwfa/s012/session_2026-08-07/run_20-17-29/vWFATask/parameters/condition_instance
# (pglRun:settings) Loading settings for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-17-29
# (pglRun:data) Loading data for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-17-29
# (pglActionRecreateExperimentDataFromTasks:run) nTriggers: 435 Mean: 1.000, SD: 0.011
# (pglRun:tasks) Loading tasks for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-33-21
# taskName: vWFATask
# (pglTask:load) Loading task data from: /Users/gru/data/vwfa/s012/session_2026-08-07/run_20-33-21/vWFATask
# (pglParameter:load) Loaded parameter condition_instance from: /Users/gru/data/vwfa/s012/session_2026-08-07/run_20-33-21/vWFATask/parameters/condition_instance
# (pglRun:settings) Loading settings for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-33-21
# (pglRun:data) Loading data for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-33-21
# (pglActionRecreateExperimentDataFromTasks:run) nTriggers: 436 Mean: 1.000, SD: 0.013
# (pglRun:tasks) Loading tasks for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-41-12
# taskName: vWFATask
# (pglTask:load) Loading task data from: /Users/gru/data/vwfa/s012/session_2026-08-07/run_20-41-12/vWFATask
# (pglParameter:load) Loaded parameter condition_instance from: /Users/gru/data/vwfa/s012/session_2026-08-07/run_20-41-12/vWFATask/parameters/condition_instance
# (pglRun:settings) Loading settings for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-41-12
# (pglRun:data) Loading data for: ssh://gru@cointreau//Users/gru/data/vwfa/s012/session_2026-08-07/run_20-41-12
# (pglActionRecreateExperimentDataFromTasks:run) nTriggers: 435 Mean: 1.000, SD: 0.016

# %%
fixedSession.runs[0].display()
