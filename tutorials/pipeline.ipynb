# %%
# autoload
# %load_ext autoreload
# %autoreload 2

# import necessary libraries
import numpy as np

# Load PGL libraries and start a PGL window
from pgl import pgl, pglChooseSession
pgl = pgl()

# close any existing windows
pgl.cleanUp()
# Out:
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:35:20) [Clang 16.0.6 ]
# (pgl:checkOS) Running on MacBook Pro (MacBookPro18,3) with macOS version: 26.5.1
# (pgl:checkOS) Apple M1 Pro Cores: 8 (6 Performance and 2 Efficiency) Memory: 32 GB
# (pgl:checkOS) GPU: Apple M1 Pro (Built-In) 14 cores, Metal 4 support
# (pgl:checkOS)   Color LCD [Main Display]: 3024 x 1964 Retina (Built-in Liquid Retina XDR Display) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglBase:removeOrphanedSockets) No orphaned sockets found in /Users/justin/Library/Containers/gru.mglMetal/Data

# %%
s = pglChooseSession("huh", dataDir="/Users/justin/data")
pgl.traitsDialog(s)
# Out:
#          937125 function calls (645928 primitive calls) in 4.478 seconds
#
#    Ordered by: cumulative time
#    List reduced from 381 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    0.000    0.000    4.478    1.493 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3631(run_code)
#         3    0.000    0.000    4.477    1.492 {built-in method builtins.exec}
#         1    0.000    0.000    4.379    4.379 /Users/justin/proj/pgl/pgl/pglDialog.py:1478(traitsDialog)
#         1    0.000    0.000    4.139    4.139 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/subprocess.py:506(run)
#         1    0.000    0.000    4.132    4.132 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/subprocess.py:1165(communicate)
#         2    0.000    0.000    4.132    2.066 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/subprocess.py:1259(wait)
#         2    0.000    0.000    4.132    2.066 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/subprocess.py:2021(_wait)
#         1    0.000    0.000    4.132    4.132 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/subprocess.py:2008(_try_wait)
#         1    4.132    4.132    4.132    4.132 {built-in method posix.waitpid}
#         1    0.000    0.000    0.239    0.239 /Users/justin/proj/pgl/pgl/pglSerialize.py:46(save)
#         1    0.000    0.000    0.239    0.239 /Users/justin/proj/pgl/pgl/pglSerialize.py:105(toJSON)
#         1    0.000    0.000    0.239    0.239 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/json/__init__.py:183(dumps)
#         1    0.002    0.002    0.239    0.239 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/json/encoder.py:183(encode)
# 153674/19496    0.019    0.000    0.237    0.000 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/json/encoder.py:414(_iterencode)
# 76837/19496    0.012    0.000    0.232    0.000 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/json/encoder.py:334(_iterencode_dict)
# 58443/19462    0.007    0.000    0.229    0.000 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/json/encoder.py:278(_iterencode_list)
# 94099/35130    0.011    0.000    0.196    0.000 {built-in method builtins.getattr}
#       541    0.001    0.000    0.195    0.000 /Users/justin/proj/pgl/pgl/pglSerialize.py:106(encodeObject)
#       541    0.001    0.000    0.195    0.000 /Users/justin/proj/pgl/pgl/pglSerialize.py:168(toJSONdict)
#      3836    0.002    0.000    0.191    0.000 /Users/justin/miniforge3/envs/pyside6-test/lib/python3.12/site-packages/traitlets/traitlets.py:676(__get__)

# %%
s.childList[0].print()
s.save("/Users/justin/huh.json")

# %%
h = pglChooseSession.load("/Users/justin/huh.json")
h.childList[5].print()
