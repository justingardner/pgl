# %% [markdown]
# ---
#
# **Setting parameters in PGL**
#
# ---

# %%
# %load_ext autoreload
# %autoreload 2
from pgl import pgl
pgl = pgl()
pgl.cleanUp()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:35:20) [Clang 16.0.6 ]
# (pgl:checkOS) Running on MacBook Pro (MacBookPro18,3) with macOS version: 26.5.1
# (pgl:checkOS) Apple M1 Pro Cores: 8 (6 Performance and 2 Efficiency) Memory: 32 GB
# (pgl:checkOS) GPU: Apple M1 Pro (Built-In) 14 cores, Metal 4 support
# (pgl:checkOS)   Color LCD [Main Display]: 3024 x 1964 Retina (Built-in Liquid Retina XDR Display) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglBase:shutdownAll) Shutting down mglMetal process: 74788
# (pglBase:shutdownAll) Shutting down mglMetal process: 74811
# (pglBase:shutdownAll) Shutting down mglMetal process: 74814
# (pglBase:removeOrphanedSockets) Removing orphaned socket: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260801_002224.UfGjmaFzXw
# (pglBase:removeOrphanedSockets) Removing orphaned socket: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260801_002247.6aszFWYzjh
# (pglBase:removeOrphanedSockets) Removing orphaned socket: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260801_002309.jOuOis7Kvw
# (pglBase:removeOrphanedSockets) Removed 3 orphaned sockets

# %% [markdown]
# ---
#
# **Overall settings for PGL**
#
# ---
#
# You use these to create different settings that are used by experiments.

# %%
pgl.settings()

# %% [markdown]
# ---
#
# **Display settings**
#
# ---
# Settings for individual displays

# %%
pgl.displaySettings()
# Out:
# (pglSerialize) Saving pglDisplaySettingsList to '/var/folders/n2/4bqdpl1s6wd9x4l9ll4p03_m0000gq/T/tmpbtr_2lcc/in.json'
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:35:20) [Clang 16.0.6 ]
# (pgl:checkOS) Running on MacBook Pro (MacBookPro18,3) with macOS version: 26.5.1
# (pgl:checkOS) Apple M1 Pro Cores: 8 (6 Performance and 2 Efficiency) Memory: 32 GB
# (pgl:checkOS) GPU: Apple M1 Pro (Built-In) 14 cores, Metal 4 support
# (pgl:checkOS)   Color LCD [Main Display]: 3024 x 1964 Retina (Built-in Liquid Retina XDR Display) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglBase:shutdownAll) Shutting down mglMetal process: 74822
# (pglBase:removeOrphanedSockets) Removing orphaned socket: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260801_002326.VS3KelN55p
# (pglBase:removeOrphanedSockets) Removed 1 orphaned sockets
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# (pgl->pglBase:validateWhichScreen) Error: Invalid screen number -1. Must be between 0 and 0.
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# ================================= pglBase:open =================================
# (pglBase:getMetalAppName) Using latest build: /Users/justin/Library/Developer/Xcode/DerivedData/Build/Products/Release/mglMetal.app
# (pglBase:open) Starting mglMetal application: /Users/justin/Library/Developer/Xcode/DerivedData/Build/Products/Release/mglMetal.app
# (pglBase:open) Using socket with address: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260801_002355.vsos6wW9Y5
# (pgl:_pglComm) .Connected to: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260801_002355.vsos6wW9Y5
# (pgl:_resolution:getResolution) Display 0/1: 1512x982 120Hz 32bits
# (pgl:pglTransform:pix2deg) xPix2Deg and yPix2Deg must be set before calling this function.
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# (pgl->pglDraw:clearScreen) Need to fix clearScreen which is not functioning properly, drawing a full screen quad instead.
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# ================================================================================
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# (pglExperiment:setGamma) Settings are set to calibrte for gamma [2.2, 1.0, 0.0] but no calibration found for display Windowed
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# (pglKeyboardMouse:start) Starting keyboard and mouse event listener.
# (pglDevices) Added device: pglKeyboard
# (pglEventListener) Eating 7 keys: ['1', '2', '3', '4', '`', 'escape', 'space']
# (Default task) Trial 1:
# (pglExperiment:startPhase) Starting phase: 0/1
# (pglExperiment:run) Experiment started.
# (Default task) Trial 2:
# Ending task Default task
# (pglExperiment:run) Experiment done.
# (pglExperiment:save) Saving experiment data to: /Users/justin/data/defaultExperiment/s0000/20260801_002404
# (pglSerialize) Saving pglState to '/Users/justin/data/defaultExperiment/s0000/20260801_002404/pgl.json'
# (pglSerialize) Saving pglSettings to '/Users/justin/data/defaultExperiment/s0000/20260801_002404/settings.json'
# (pglSerialize) Saving pglExperimentSettings to '/Users/justin/data/defaultExperiment/s0000/20260801_002404/experimentSettings.json'
# (pglSerialize) Saving pglExperimentState to '/Users/justin/data/defaultExperiment/s0000/20260801_002404/state.json'
# (pglSerialize) Saving pglExperimentData to '/Users/justin/data/defaultExperiment/s0000/20260801_002404/data.json'
# (pglSerialize) Saving pglTaskSettings to '/Users/justin/data/defaultExperiment/s0000/20260801_002404/defaultTask/settings.json'
# (pglSerialize) Saving pglTaskState to '/Users/justin/data/defaultExperiment/s0000/20260801_002404/defaultTask/state.json'
# (pglSerialize) Saving pglTaskData to '/Users/justin/data/defaultExperiment/s0000/20260801_002404/defaultTask/data.json'
# (pglExperiment:endScreen) Stopping keyboard/mouse device.
# <pglDevice type=pglKeyboard>
# (pglKeyboardMouse:stop) Stopping keyboard listener.
# ================================ pglBase:close =================================
# (pglBase:close) Closing connection to mglMetal application
# (pglBase:close) Closing mglMetal application with PID 74833
# (pglBase:close) mglMetal application with PID: 74833 was killed successfully.
# (pgl:_pglComm) Closed socket: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260801_002355.vsos6wW9Y5
# ================================================================================
# pglDisplaySettingsWindowed:
# ----------------------------------------
# name                           Windowed
# uuid                           windowed
# vendor                         0
# model                          0
# serialNumber                   0
# currentDisplayNum              -1
# currentDisplayMode             (800, 600, 60.0)
# isMain                         False
# isBuiltin                      False
# gammaTableSize                 -1
# flipLeftRight                  False
# flipUpDown                     False
# displayDistance                57.0
# displaySize                    (30.0, 20.0)
# windowPosition                 (0, 0)
# windowSize                     (800, 600)
# pixelDims                      [<pgl.pglSettings.pglDisplayModeSettings object at 0x16a2bbec0>]
# luminanceCalibration           ['None']
# temporalCalibration            ['None']
# pglDisplayModeSettings:
# ----------------------------------------
# name                           default
# uuid                           4a54ced6-0a72-4ab5-8fe0-8679fd93d2af
# modeName                       800 x 600
# pixelDims                      (800, 600)
# refreshRate                    [60.0]
# (pglBase) Main library closed

# %%
## TODO
# accessibility warning, should display on screen in a visible way, maybe before opening screen
# deal with calibration / validation
# handle "latest"
