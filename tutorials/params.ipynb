# %% [markdown]
# Setting screen params

# %%
# %load_ext autoreload
# %autoreload 2
from traitlets import HasTraits, Float, Int, Unicode, link
import ipywidgets as widgets
from IPython.display import display, HTML
from pgl import pglScreenSettings
from pgl import pgl
pgl = pgl()

# %%
pgl.getScreenSettingsDir()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pgl.getScreenSettingsDir()
#
# TypeError: pglSettingsManager.getScreenSettingsDir() missing 1 required positional argument: 'self'

# %%
# edit settings
p = pglScreenSettings()
p.edit()

# %%
#print(p)
p.save("test.json")

# %%
p.load('test.json')
print(p)

# %%
print(p)

# %%
import ipywidgets as widgets
out = widgets.Output()
out.clear_output(wait=True)

# %%
from pgl import pglExperiment, pgl
pgl = pgl()
e = pglExperiment(pgl)

# %%
e.getScreenSettings()

# %%
print(p.alpha, p.n_iter, p.name, p.options, p.distance, p.width, p.height)

# %%
import ipywidgets as widgets
out=widgets.Output()
out.clear_output(wait=True)
