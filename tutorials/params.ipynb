# %% [markdown]
# Setting screen params

# %%
# %load_ext autoreload
# %autoreload 2
from pgl import pgl
pgl = pgl()
pgl.cleanUp()
from pgl import pglExperiment
e = pglExperiment(pgl, settingsName="Window")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.13 | packaged by conda-forge | (main, Mar  5 2026, 17:06:14) [Clang 19.1.7 ]
# (pgl:checkOS) Running on Mac mini (Macmini9,1) with macOS version: 14.4.1
# (pgl:checkOS) Apple M1 Cores: 8 (4 performance and 4 efficiency) Memory: 8 GB
# (pgl:checkOS) GPU: Apple M1 (Built-In) 8 cores, Metal 3 support
# (pgl:checkOS)   Acer K272HUL [Main Display]: 2560 x 1440 (QHD/WQHD - Wide Quad High Definition) (Unknown type) GammaTable size: 1024
# (pgl:checkOS)   KEY DIGITAL14: 1920 x 1080 (1080p FHD - Full High Definition) (Unknown type) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglBase:shutdownAll) Shutting down mglMetal process: 38226
# (pglBase:removeOrphanedSockets) Removing orphaned socket: /Users/gru/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260320_122025.ZD17OeeKYk
# (pglBase:removeOrphanedSockets) Removed 1 orphaned sockets
# (pglSettingsManager:loadSettings) Settings file '/Users/gru/.pgl/settings/Window.json' not found.
# <b>(pglExperiment:initScreen)</b> ❌ Could not find settings, using default settings.

# %%
pgl.settings()
# Out:
# (pglExperiment) No settings provided, using default settings.
# (pglSerialize) 'commandRecord' not found in '<dict>', using default True
#         <style>
#         .dark-widget-card {
#             background-color: #000 !important;
#             border: 1px solid #333;
#             border-radius: 8px;
#             padding: 16px;
#         }
#
#         .dark-widget-card .widget-label {
#             color: #eaeaea !important;
#         }
#
#         .dark-widget-card input,
#         .dark-widget-card textarea,
#         .dark-widget-card select {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#             border: 1px solid #444 !important;
#         }
#
#         .dark-widget-card .slider {
#             background-color: #222 !important;
#         }
#
#         .dark-widget-card select option {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#         }
#
#         .help-text, .options-panel {
#             background-color: #111;
#             color: #eaeaea;
#             border: 1px solid #444;
#             border-radius: 5px;
#             padding: 8px;
#         }
#         </style>
# Box(children=(Box(children=(Dropdown(description='settingsNames', layout=Layout(width='100%'), options=('CNI_p…
#         <style>
#         .dark-widget-card {
#             background-color: #000 !important;
#             border: 1px solid #333;
#             border-radius: 8px;
#             padding: 16px;
#         }
#
#         .dark-widget-card .widget-label {
#             color: #eaeaea !important;
#         }
#
#         .dark-widget-card input,
#         .dark-widget-card textarea,
#         .dark-widget-card select {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#             border: 1px solid #444 !important;
#         }
#
#         .dark-widget-card .slider {
#             background-color: #222 !important;
#         }
#
#         .dark-widget-card select option {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#         }
#
#         .help-text, .options-panel {
#             background-color: #111;
#             color: #eaeaea;
#             border: 1px solid #444;
#             border-radius: 5px;
#             padding: 8px;
#         }
#         </style>
# Box(children=(Box(children=(Text(value='CNI_projector', description='settingsName', layout=Layout(width='100%'…

# %%
from pgl import pglKeyboardMouse
km = pglKeyboardMouse()
#km.checkAccessibilityPermission()

# %%
from pgl import pglEventListener
listener = pglEventListener()
listener.start()

# %%
from pgl import pgl
from pgl import pglExperiment, pglTestTask
pgl = pgl()
e = pglExperiment(pgl,settingsName="Window")
                
# initialize task
t = pglTestTask(pgl)
e.addTask(t)
        
# open screen
e.initScreen()
        
# and run
e.run()

# %%
km.poll()

# %%
from pgl import pglSettings
# edit settings
p = pglSettings()
p.edit()

# %%
#print(p)
p.save("test.json")

# %%
p.load('test.json')
print(p)

# %%
print(p)

# %%
import ipywidgets as widgets
out = widgets.Output()
out.clear_output(wait=True)

# %%
from pgl import pglExperiment, pgl
pgl = pgl()
e = pglExperiment(pgl)

# %%
e.getScreenSettings()

# %%
print(p.alpha, p.n_iter, p.name, p.options, p.distance, p.width, p.height)

# %%
import ipywidgets as widgets
out=widgets.Output()
out.clear_output(wait=True)

# %%
list("1"+"2")+list("34")+list("")
