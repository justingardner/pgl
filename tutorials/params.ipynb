# %% [markdown]
# ---
#
# **Setting parameters in PGL**
#
# ---

# %%
# %load_ext autoreload
# %autoreload 2
from pgl import pgl
pgl = pgl()
pgl.cleanUp()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# (pglBase) Main library closed
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.13 | packaged by conda-forge | (main, Mar  5 2026, 17:06:14) [Clang 19.1.7 ]
# (pgl:checkOS) Running on Mac Studio (Mac16,9) with macOS version: 26.5.2
# (pgl:checkOS) Apple M4 Max Cores: 14 (10 Performance and 4 Efficiency) Memory: 36 GB
# (pgl:checkOS) GPU: Apple M4 Max (Built-In) 32 cores, Metal 4 support
# ...

# %% [markdown]
# ---
#
# **Overall settings for PGL**
#
# ---
#
# You use these to create different settings that are used by experiments.

# %%
pgl.settings()
# Out:
# (pglSerialize) Saving pglSettingsList to '/var/folders/lx/cdzh2nj93njbpsjzt77snd_80000gp/T/tmpbw7mf680/in.json'
# (pgl) Warning: pylink not found, pglEyelink class will not be available. Download with: pip install sr-research-pylink
# (pglSerialize) Saving pglSettingsList to '/var/folders/lx/cdzh2nj93njbpsjzt77snd_80000gp/T/tmpbw7mf680/out.json'
# (pglSerialize) Saving pglSettings to '/Users/justin/.pgl/settings/propixx.json'

# %% [markdown]
# ---
#
# **Display settings**
#
# ---
# Settings for individual displays

# %%
pgl.displaySettings()
# Out:
# (pglSerialize) Saving pglDisplaySettingsList to '/var/folders/lx/cdzh2nj93njbpsjzt77snd_80000gp/T/tmpasryxbeg/in.json'
# (pgl) Warning: pylink not found, pglEyelink class will not be available. Download with: pip install sr-research-pylink
# (pglDisplayLuminanceCalibrationData:load) Loading /Users/justin/.pgl/displays/datapixx3_rx1/luminance/20260731_174550/calibration
# (pglDisplayLuminanceCalibrationData:load) Loading /Users/justin/.pgl/displays/datapixx3_rx1/luminance/20260731_174550/calibration

# %%
## TODO
# accessibility warning, should display on screen in a visible way, maybe before opening screen
# the default width x height x hertz should be the current one
# add / copy / delete buttons working
# Windowed context
# deal with calibration / validation
