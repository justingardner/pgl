# %% [markdown]
# Setting screen params

# %%
# %load_ext autoreload
# %autoreload 2
from pgl import pgl
pgl = pgl()
pgl.cleanUp()
from pgl import pglExperiment
e = pglExperiment(pgl, suppressInitScreen=True)
# Out:
# ================================ pglBase: init =================================
# (pgl:checkOS) Python version: 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:35:20) [Clang 16.0.6 ]
# (pgl:checkOS) Running on MacBook Pro (MacBookPro18,3) with macOS version: 26.2
# (pgl:checkOS) Apple M1 Pro Cores: 8 (6 performance and 2 efficiency) Memory: 32 GB
# (pgl:checkOS) GPU: Apple M1 Pro (Built-In) 14 cores, Metal 4 support
# (pgl:checkOS)   Color LCD [Main Display]: 3024 x 1964 Retina (Built-in Liquid Retina XDR Display) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglBase:removeOrphanedSockets) Removing orphaned socket: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260214_230655.dGlUiKV3ks
# (pglBase:removeOrphanedSockets) Removing orphaned socket: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260214_223707.SzITie3WkD
# (pglBase:removeOrphanedSockets) Removed 2 orphaned sockets

# %%
p = e.getScreenSettings("Default")
p.edit()
# Out:
# (pglSettingsManager:loadSettings) Loading settings from '/Users/justin/.pgl/screenSettings/Default.json'.
#         <style>
#         .dark-widget-card {
#             background-color: #000 !important;
#             border: 1px solid #333;
#             border-radius: 8px;
#             padding: 16px;
#         }
#
#         .dark-widget-card .widget-label {
#             color: #eaeaea !important;
#         }
#
#         .dark-widget-card input,
#         .dark-widget-card textarea,
#         .dark-widget-card select {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#             border: 1px solid #444 !important;
#         }
#
#         .dark-widget-card .slider {
#             background-color: #222 !important;
#         }
#
#         .dark-widget-card select option {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#         }
#
#         .help-text, .options-panel {
#             background-color: #111;
#             color: #eaeaea;
#             border: 1px solid #444;
#             border-radius: 5px;
#             padding: 8px;
#         }
#         </style>
# Box(children=(Box(children=(Text(value='Default', description='displayName', layout=Layout(width='100%'), styl…

# %%
# edit settings
p = pglScreenSettings()
p.edit()

# %%
#print(p)
p.save("test.json")

# %%
p.load('test.json')
print(p)

# %%
print(p)

# %%
import ipywidgets as widgets
out = widgets.Output()
out.clear_output(wait=True)

# %%
from pgl import pglExperiment, pgl
pgl = pgl()
e = pglExperiment(pgl)

# %%
e.getScreenSettings()

# %%
print(p.alpha, p.n_iter, p.name, p.options, p.distance, p.width, p.height)

# %%
import ipywidgets as widgets
out=widgets.Output()
out.clear_output(wait=True)
