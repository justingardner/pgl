# %% [markdown]
# Setting screen params

# %%
# %load_ext autoreload
# %autoreload 2
from pgl import pgl
pgl = pgl()
pgl.cleanUp()
from pgl import pglExperiment
e = pglExperiment(pgl, suppressInitScreen=True)
# Out:
# ================================ pglBase: init =================================
# (pgl:checkOS) Python version: 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:35:20) [Clang 16.0.6 ]
# (pgl:checkOS) Running on MacBook Pro (MacBookPro18,3) with macOS version: 26.2
# (pgl:checkOS) Apple M1 Pro Cores: 8 (6 performance and 2 efficiency) Memory: 32 GB
# (pgl:checkOS) GPU: Apple M1 Pro (Built-In) 14 cores, Metal 4 support
# (pgl:checkOS)   Color LCD [Main Display]: 3024 x 1964 Retina (Built-in Liquid Retina XDR Display) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglBase:removeOrphanedSockets) No orphaned sockets found in /Users/justin/Library/Containers/gru.mglMetal/Data

# %%
pgl.settings()
# Out:
#         <style>
#         .dark-widget-card {
#             background-color: #000 !important;
#             border: 1px solid #333;
#             border-radius: 8px;
#             padding: 16px;
#         }
#
#         .dark-widget-card .widget-label {
#             color: #eaeaea !important;
#         }
#
#         .dark-widget-card input,
#         .dark-widget-card textarea,
#         .dark-widget-card select {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#             border: 1px solid #444 !important;
#         }
#
#         .dark-widget-card .slider {
#             background-color: #222 !important;
#         }
#
#         .dark-widget-card select option {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#         }
#
#         .help-text, .options-panel {
#             background-color: #111;
#             color: #eaeaea;
#             border: 1px solid #444;
#             border-radius: 5px;
#             padding: 8px;
#         }
#         </style>
# Box(children=(Box(children=(Dropdown(description='settingsNames', layout=Layout(width='100%'), options=('Main …
#         <style>
#         .dark-widget-card {
#             background-color: #000 !important;
#             border: 1px solid #333;
#             border-radius: 8px;
#             padding: 16px;
#         }
#
#         .dark-widget-card .widget-label {
#             color: #eaeaea !important;
#         }
#
#         .dark-widget-card input,
#         .dark-widget-card textarea,
#         .dark-widget-card select {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#             border: 1px solid #444 !important;
#         }
#
#         .dark-widget-card .slider {
#             background-color: #222 !important;
#         }
#
#         .dark-widget-card select option {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#         }
#
#         .help-text, .options-panel {
#             background-color: #111;
#             color: #eaeaea;
#             border: 1px solid #444;
#             border-radius: 5px;
#             padding: 8px;
#         }
#         </style>
# Box(children=(Box(children=(Text(value='Main Display', description='settingsName', layout=Layout(width='100%')…
# VBox(children=(HTML(value='<b>Are you sure you want to delete?</b>'), HBox(children=(Button(button_style='succ…
# Output()
#         <style>
#         .dark-widget-card {
#             background-color: #000 !important;
#             border: 1px solid #333;
#             border-radius: 8px;
#             padding: 16px;
#         }
#
#         .dark-widget-card .widget-label {
#             color: #eaeaea !important;
#         }
#
#         .dark-widget-card input,
#         .dark-widget-card textarea,
#         .dark-widget-card select {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#             border: 1px solid #444 !important;
#         }
#
#         .dark-widget-card .slider {
#             background-color: #222 !important;
#         }
#
#         .dark-widget-card select option {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#         }
#
#         .help-text, .options-panel {
#             background-color: #111;
#             color: #eaeaea;
#             border: 1px solid #444;
#             border-radius: 5px;
#             padding: 8px;
#         }
#         </style>
# Box(children=(Box(children=(Text(value='Main', description='settingsName', layout=Layout(width='100%'), style=…
#         <style>
#         .dark-widget-card {
#             background-color: #000 !important;
#             border: 1px solid #333;
#             border-radius: 8px;
#             padding: 16px;
#         }
#
#         .dark-widget-card .widget-label {
#             color: #eaeaea !important;
#         }
#
#         .dark-widget-card input,
#         .dark-widget-card textarea,
#         .dark-widget-card select {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#             border: 1px solid #444 !important;
#         }
#
#         .dark-widget-card .slider {
#             background-color: #222 !important;
#         }
#
#         .dark-widget-card select option {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#         }
#
#         .help-text, .options-panel {
#             background-color: #111;
#             color: #eaeaea;
#             border: 1px solid #444;
#             border-radius: 5px;
#             padding: 8px;
#         }
#         </style>
# Box(children=(Box(children=(Text(value='Windowed Display', description='settingsName', layout=Layout(width='10…
# VBox(children=(HTML(value='<b>Are you sure you want to delete?</b>'), HBox(children=(Button(button_style='succ…
# Output()
#         <style>
#         .dark-widget-card {
#             background-color: #000 !important;
#             border: 1px solid #333;
#             border-radius: 8px;
#             padding: 16px;
#         }
#
#         .dark-widget-card .widget-label {
#             color: #eaeaea !important;
#         }
#
#         .dark-widget-card input,
#         .dark-widget-card textarea,
#         .dark-widget-card select {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#             border: 1px solid #444 !important;
#         }
#
#         .dark-widget-card .slider {
#             background-color: #222 !important;
#         }
#
#         .dark-widget-card select option {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#         }
#
#         .help-text, .options-panel {
#             background-color: #111;
#             color: #eaeaea;
#             border: 1px solid #444;
#             border-radius: 5px;
#             padding: 8px;
#         }
#         </style>
# Box(children=(Box(children=(Text(value='Main', description='settingsName', layout=Layout(width='100%'), style=…
#         <style>
#         .dark-widget-card {
#             background-color: #000 !important;
#             border: 1px solid #333;
#             border-radius: 8px;
#             padding: 16px;
#         }
#
#         .dark-widget-card .widget-label {
#             color: #eaeaea !important;
#         }
#
#         .dark-widget-card input,
#         .dark-widget-card textarea,
#         .dark-widget-card select {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#             border: 1px solid #444 !important;
#         }
#
#         .dark-widget-card .slider {
#             background-color: #222 !important;
#         }
#
#         .dark-widget-card select option {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#         }
#
#         .help-text, .options-panel {
#             background-color: #111;
#             color: #eaeaea;
#             border: 1px solid #444;
#             border-radius: 5px;
#             padding: 8px;
#         }
#         </style>
# Box(children=(Box(children=(Text(value='Window', description='settingsName', layout=Layout(width='100%'), styl…

# %%
from pgl import pglKeyboardMouse
km = pglKeyboardMouse()
#km.checkAccessibilityPermission()

# %%
from pgl import pglEventListener
listener = pglEventListener()
listener.start()

# %%
from pgl import pgl
from pgl import pglExperiment, pglTestTask
pgl = pgl()
e = pglExperiment(pgl, suppressInitScreen=True)
                
# initialize task
t = pglTestTask(pgl)
e.addTask(t)
        
# open screen
e.initScreen(settings="Window")
        
# and run
e.run()
# Out:
# ================================ pglBase: init =================================
# (pgl:checkOS) Python version: 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:35:20) [Clang 16.0.6 ]
# (pgl:checkOS) Running on MacBook Pro (MacBookPro18,3) with macOS version: 26.2
# (pgl:checkOS) Apple M1 Pro Cores: 8 (6 performance and 2 efficiency) Memory: 32 GB
# (pgl:checkOS) GPU: Apple M1 Pro (Built-In) 14 cores, Metal 4 support
# (pgl:checkOS)   Color LCD [Main Display]: 3024 x 1964 Retina (Built-in Liquid Retina XDR Display) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglSettingsManager:loadSettings) Settings file '/Users/justin/.pgl/settings/Default.json' not found.
# <b>(pglExperiment:initScreen)</b> ❌ Could not find settings to open screen.
# (pglExperiment:run) Waiting for key press (['Key.space']) to start experiment...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 14
#      11 e.initScreen()
#      13 # and run
# ---> 14 e.run()
#
# File ~/proj/pgl/pgl/pglExperiment.py:155, in pglExperiment.run(self)
#     153 experimentStarted = False
#     154 print(f"(pglExperiment:run) Waiting for key press ({[key for key in self.startKeypress]}) to start experiment...")
# --> 155 while not experimentStarted:
#     156     # poll for events
#     157     events = self.pgl.poll()
#     159     # see if we have a match to startKeypress
#
# KeyboardInterrupt:

# %%
km.poll()

# %%
from pgl import pglSettings
# edit settings
p = pglSettings()
p.edit()

# %%
#print(p)
p.save("test.json")

# %%
p.load('test.json')
print(p)

# %%
print(p)

# %%
import ipywidgets as widgets
out = widgets.Output()
out.clear_output(wait=True)

# %%
from pgl import pglExperiment, pgl
pgl = pgl()
e = pglExperiment(pgl)

# %%
e.getScreenSettings()

# %%
print(p.alpha, p.n_iter, p.name, p.options, p.distance, p.width, p.height)

# %%
import ipywidgets as widgets
out=widgets.Output()
out.clear_output(wait=True)
