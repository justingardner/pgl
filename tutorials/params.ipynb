# %% [markdown]
# ---
#
# **Setting parameters in PGL**
#
# ---

# %%
# %load_ext autoreload
# %autoreload 2
from pgl import pgl
pgl = pgl()
pgl.cleanUp()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:35:20) [Clang 16.0.6 ]
# (pgl:checkOS) Running on MacBook Pro (MacBookPro18,3) with macOS version: 26.5.1
# (pgl:checkOS) Apple M1 Pro Cores: 8 (6 Performance and 2 Efficiency) Memory: 32 GB
# (pgl:checkOS) GPU: Apple M1 Pro (Built-In) 14 cores, Metal 4 support
# (pgl:checkOS)   Color LCD [Main Display]: 3024 x 1964 Retina (Built-in Liquid Retina XDR Display) GammaTable size: 1024
# ...

# %% [markdown]
# ---
#
# **Overall settings for PGL**
#
# ---
#
# You use these to create different settings that are used by experiments.

# %%
pgl.settings()

# %% [markdown]
# ---
#
# **Display settings**
#
# ---
# Settings for individual displays

# %%
pgl.displaySettings()
# Out:
# duh
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# (pglDialog:traitsDialog) Error running traitsDialog: pglSerialize.save() takes 2 positional arguments but 3 were given
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌

# %%
from pgl import pglDisplaySettings
display = pglDisplaySettings.load("built-in retina display")
display.save(deepSave=True)
#display.print()
# Out:
# (pglDisplaySettings:save) Saved display settings to /Users/justin/.pgl/displays/built-in_retina_display/display.json
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 from pgl import pglDisplaySettings
#       2 display = pglDisplaySettings.load("built-in retina display")
# ----> 3 display.save(deepSave=True)
#
# File ~/proj/pgl/pgl/pglSettings.py:855, in save(self, filename, deepSave)
#     853 if deepSave:
#     854     for c in luminanceCalibration:
# --> 855         luminanceCalibrationDir = pglSettingsManager.getDisplayLuminanceCalibrationDir(displaySettings=self)
#     856         luminanceCalibration = pglSettingsManager.getCalibrations(luminanceCalibrationDir, [c])
#     857         luminanceCalibration.print()
#
# UnboundLocalError: cannot access local variable 'luminanceCalibration' where it is not associated with a value

# %%
## TODO
# accessibility warning, should display on screen in a visible way, maybe before opening screen
# deal with calibration / validation
