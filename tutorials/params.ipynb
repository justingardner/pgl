# %% [markdown]
# ---
#
# **Setting parameters in PGL**
#
# ---

# %%
# %load_ext autoreload
# %autoreload 2
from pgl import pgl
pgl = pgl()
pgl.cleanUp()
# Out:
# (pgl) Warning: pylink not found, pglEyelink class will not be available. Download with: pip install sr-research-pylink
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.13 | packaged by conda-forge | (main, Mar  5 2026, 17:06:14) [Clang 19.1.7 ]
# (pgl:checkOS) Running on Mac Studio (Mac16,9) with macOS version: 26.5.2
# (pgl:checkOS) Apple M4 Max Cores: 14 (10 Performance and 4 Efficiency) Memory: 36 GB
# (pgl:checkOS) GPU: Apple M4 Max (Built-In) 32 cores, Metal 4 support
# (pgl:checkOS)   DELL U2724DE [Main Display]: 2560 x 1440 (QHD/WQHD - Wide Quad High Definition) (Unknown type) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglBase:removeOrphanedSockets) No orphaned sockets found in /Users/justin/Library/Containers/gru.mglMetal/Data

# %% [markdown]
# ---
#
# **Overall settings for PGL**
#
# ---
#
# You use these to create different settings that are used by experiments.

# %%
pgl.settings()

# %% [markdown]
# ---
#
# **Display settings**
#
# ---
# Settings for individual displays

# %%
pgl.displaySettings()
# Out:
# (pglSerialize) Saving pglDisplaySettingsList to '/var/folders/lx/cdzh2nj93njbpsjzt77snd_80000gp/T/tmpu7cpmi7z/in.json'
# (pgl) Warning: pylink not found, pglEyelink class will not be available. Download with: pip install sr-research-pylink
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.13 | packaged by conda-forge | (main, Mar  5 2026, 17:06:14) [Clang 19.1.7 ]
# (pgl:checkOS) Running on Mac Studio (Mac16,9) with macOS version: 26.5.2
# (pgl:checkOS) Apple M4 Max Cores: 14 (10 Performance and 4 Efficiency) Memory: 36 GB
# (pgl:checkOS) GPU: Apple M4 Max (Built-In) 32 cores, Metal 4 support
# (pgl:checkOS)   DELL U2724DE [Main Display]: 2560 x 1440 (QHD/WQHD - Wide Quad High Definition) (Unknown type) GammaTable size: 1024
# (pglBase) Main library instance created
# ================================================================================
# (pglBase:removeOrphanedSockets) No orphaned sockets found in /Users/justin/Library/Containers/gru.mglMetal/Data
# (pgl:_resolution:getResolution) Display 0/1: 2560x1440 120Hz 32bits
# (pgl:_resolution:setBestMode) Setting display 4 to 800x600 120Hz 32 bits
# (pgl:_resolution:setBestMode) Setting display 4 to 800x600 120Hz 32 bits
# (pgl:_resolution:getResolution) Display 0/1: 800x600 120Hz 32bits
# (pgl:_resolution:getResolution) Display 0/1: 800x600 120Hz 32bits
# (pglExperiment:initScreen) Changing screen resolution to: 800 x 600 120Hz 32bits from: 2560 x 1440 120Hz 32bits
# ================================= pglBase:open =================================
# (pglBase:open) Starting mglMetal application: /Users/justin/proj/pgl/metal/mglMetal.app
# (pglBase:open) Using socket with address: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260730_155404.SKUrlmlxjX
# (pgl:_pglComm) .Connected to: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260730_155404.SKUrlmlxjX
# (pgl:_resolution:getResolution) Display 0/1: 800x600 120Hz 32bits
# (pgl:pglTransform:pix2deg) xPix2Deg and yPix2Deg must be set before calling this function.
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# (pgl->pglDraw:clearScreen) Need to fix clearScreen which is not functioning properly, drawing a full screen quad instead.
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# ================================================================================
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# (pglExperiment:setGamma) Settings are set to calibrte for gamma {settings.calibrateForGamma} but no calibration found for display {display.name}
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# (pglKeyboardMouse) ❌ Accessibility permission required. Go to System Preferences > Security & Privacy > Privacy > Accessibility and add Python/Terminal
# (pglKeyboardMouse) ❌ This app is not authorized for Accessibility input monitoring. No keyboard events will be detected!!
#   Go to System Settings → Privacy & Security → Accessibility and add this app.
#   If you are running VS Code and it already has permissions granted, try running directly from a terminal with:
#   /Applications/Visual\ Studio\ Code.app/Contents/MacOS/Electron
# (pglDevices) Added device: pglKeyboard
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# (pglExperiment:initScreen) Accessibility permission not granted for keyboard/mouse access.
# On macOS, go to System Preferences -> Security & Privacy -> Privacy -> Accessibility
# and add your terminal application (e.g. Terminal, iTerm, etc) to the list of apps allowed to control your computer.
# If you are running VS Code and it already has permissions granted, try running directly from a terminal with:
#     /Applications/Visual\ Studio\ Code.app/Contents/MacOS/Electron
# ❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌❌
# (pglExperiment:endScreen) Stopping keyboard/mouse device.
# <pglDevice type=pglKeyboard>
# (pglKeyboardMouse:stop) Stopping keyboard listener.
# (pgl:_resolution:setBestMode) Setting display 4 to 2560x1440 120Hz 32 bits
# (pgl:_resolution:setBestMode) Setting display 4 to 2560x1440 120Hz 32 bits
# (pgl:_resolution:getResolution) Display 0/1: 2560x1440 120Hz 32bits
# (pglExperiment:endScreen) Restoring resolution back to: 2560 x 1440 120Hz 32bits
# ================================ pglBase:close =================================
# (pglBase:close) Closing connection to mglMetal application
# (pglBase:close) Closing mglMetal application with PID 60481
# (pglBase:close) mglMetal application with PID: 60481 was killed successfully.
# (pgl:_pglComm) Closed socket: /Users/justin/Library/Containers/gru.mglMetal/Data/pglMetal.socket.20260730_155404.SKUrlmlxjX
# ================================================================================

# %%
d = pgl.getDisplaySettings()
d[0].print()
d[0].displayModes[0].print()
# Out:
# pglDisplaySettings:
# ----------------------------------------
# name                           DELL U2724DE
# uuid                           497E90B9-97FC-45DB-9225-F07769F5883B
# vendor                         4268
# model                          17122
# serialNumber                   1144343884
# isMain                         True
# isBuiltin                      False
# flipLeftRight                  False
# flipUpDown                     False
# currentDisplayNum              0
# gammaTableSize                 1024
# displayDistance                57.0
# displaySize                    (30.0, 20.0)
# pixelDims                      [<pgl.pglSettings.pglDisplayModeSettings object at 0x176eefbc0>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef9b0>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef920>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef980>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef8f0>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eefa70>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176a74f50>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eefb60>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef620>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef800>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef830>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef590>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef740>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef7a0>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef770>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eef3b0>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eee750>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eee660>, <pgl.pglSettings.pglDisplayModeSettings object at 0x176eee330>]
# luminanceCalibration           ['None']
# temporalCalibration            ['None']
# pglDisplayModeSettings:
# ----------------------------------------
# name                           default
# uuid                           b713147b-32f7-41be-aaad-cfc19dbf6430
# modeName                       800 x 600
# pixelDims                      (800, 600)
# refreshRate                    [120.0, 75.0, 60.0]
