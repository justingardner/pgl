# %% [markdown]
# Setting screen params

# %%
# %pdb
# %load_ext autoreload
# %autoreload 2
from pgl import pgl
pgl = pgl()
pgl.cleanUp()
from pgl import pglExperiment
e = pglExperiment(pgl, settingsName="Window")
# Out:
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:35:20) [Clang 16.0.6 ]
# (pgl:checkOS) Running on MacBook Pro (MacBookPro18,3) with macOS version: 26.3
# (pgl:checkOS) Apple M1 Pro Cores: 8 (6 Performance and 2 Efficiency) Memory: 32 GB
# (pgl:checkOS) GPU: Apple M1 Pro (Built-In) 14 cores, Metal 4 support
# (pgl:checkOS)   Color LCD [Main Display]: 3024 x 1964 Retina (Built-in Liquid Retina XDR Display) GammaTable size: 1024
# (pglBase) Main library instance created
# ...
# (pglBase:shutdownAll) Shutting down mglMetal process: 16944
# ...

# %%
pgl.settings()
# Out:
# (pglSettingsManager:loadSettings) Settings file '/Users/justin/.pgl/settings/Default.json' not found.
# <b>(pglExperiment:initScreen)</b> ❌ Could not find settings, using default settings.
# (pglSerialize) 'startOnVolumeTrigger' not found in '/Users/justin/.pgl/settings/Main.json', using default False
# (pglSerialize) 'startOnVolumeTrigger' not found in '/Users/justin/.pgl/settings/Window.json', using default False
#         <style>
#         .dark-widget-card {
#             background-color: #000 !important;
#             border: 1px solid #333;
#             border-radius: 8px;
#             padding: 16px;
#         }
#
#         .dark-widget-card .widget-label {
#             color: #eaeaea !important;
#         }
#
#         .dark-widget-card input,
#         .dark-widget-card textarea,
#         .dark-widget-card select {
#             background-color: #111 !important;
#             color: #eaeaea !important;
#             border: 1px solid #444 !important;
#         }
#
# ...

# %%
from pgl import pglKeyboardMouse
km = pglKeyboardMouse()
#km.checkAccessibilityPermission()

# %%
from pgl import pglEventListener
listener = pglEventListener()
listener.start()

# %%
from pgl import pgl
from pgl import pglExperiment, pglTestTask
pgl = pgl()
e = pglExperiment(pgl,settingsName="Window")
                
# initialize task
t = pglTestTask(pgl)
e.addTask(t)
        
# open screen
e.initScreen()
        
# and run
e.run()

# %%
km.poll()

# %%
from pgl import pglSettings
# edit settings
p = pglSettings()
p.edit()

# %%
#print(p)
p.save("test.json")

# %%
p.load('test.json')
print(p)

# %%
print(p)

# %%
import ipywidgets as widgets
out = widgets.Output()
out.clear_output(wait=True)

# %%
from pgl import pglExperiment, pgl
pgl = pgl()
e = pglExperiment(pgl)

# %%
e.getScreenSettings()

# %%
print(p.alpha, p.n_iter, p.name, p.options, p.distance, p.width, p.height)

# %%
import ipywidgets as widgets
out=widgets.Output()
out.clear_output(wait=True)

# %%
list("1"+"2")+list("34")+list("")
