# %% [markdown]
# Movie display tutorial

# %%
# setup autoreload
# %load_ext autoreload
# %autoreload 2

# Load PGL libraries and start a PGL window
from pgl import pgl as pglLibrary
pgl = pglLibrary()

# close any existing windows
pgl.cleanUp()

# open a new window
pgl.open(0,800,600)
pgl.visualAngle(57, 60, 45)
# Out:
# ================================ pglBase: init =================================
# (pgl) mglMetal error log can be viewed in MacOS Console app by searching for PROCESS mglMetal or in a terminal with:
#       log stream --level info --process mglMetal
# (pgl) To search for something specifc, e.g. messages from mglMovie:
#       log stream --predicate 'eventMessage CONTAINS "mglMovie"' --style syslog --level info
# (pgl:checkOS) Python version: 3.12.3 | packaged by conda-forge | (main, Apr 15 2024, 18:35:20) [Clang 16.0.6 ]
# (pgl:checkOS) Running on MacBook Pro (MacBookPro18,3) with macOS version: 26.3
# (pgl:checkOS) Apple M1 Pro Cores: 8 (6 Performance and 2 Efficiency) Memory: 32 GB
# (pgl:checkOS) GPU: Apple M1 Pro (Built-In) 14 cores, Metal 4 support
# (pgl:checkOS)   Color LCD [Main Display]: 3024 x 1964 Retina (Built-in Liquid Retina XDR Display) GammaTable size: 1024
# (pglBase) Main library instance created
# ...
# (pglBase:shutdownAll) Shutting down mglMetal process: 6849
# ...

# %% [markdown]
# Load a movie

# %%
m = pgl.movie("/Users/justin/Movies/testvideo.mp4", x=0, y=0, displayWidth=30, displayHeight=15, xAlign=1, yAlign=0);
#m = pgl.movie("/Users/justin/Movies/testvideo.mp4", displayWidth =60);
#m = pgl.movie("/Users/justin/Movies/beach.mp4", displayWidth =18, displayHeight=32);
#m = pgl.movie("/Users/justin/Movies/colortest.mp4");
#m = pgl.movie("/Users/justin/Movies/puffins.MOV");
#m = pgl.movie("/Users/justin/Movies/wedding.MOV", displayWidth = 32, displayHeight = 18);
#m = pgl.movie("/Users/justin/Movies/shosta.mov", displayWidth = 15)
#m = pgl.movie("/Users/justin/Movies/floatingrock.MOV", displayWidth = 32, displayHeight = 18);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 m = pgl.movie("/Users/justin/Movies/testvideo.mp4", 0, 0, 30, 15, 1,0)
#
# TypeError: pglStimuli.movie() takes 2 positional arguments but 8 were given

# %% [markdown]
# Display the movie and show the frame statistics

# %%
# start by flushing the screen to get the display loop going (this would normally done in the expt code)
pgl.flush(); pgl.flush(); pgl.flush(); pgl.flush();

# play the movie
m.play()
# Out:
# (pglStimulusMovie:play) Movie played 130 frames.
# ...

# %%
m.status()
m.print()
#m.setDisplayPosition(displayWidth=301,y=-40,x=5)
#m.setDisplayPosition(displayWidth=-30,displayHeight=18)
m.setDisplayPosition(displayWidth=15)
